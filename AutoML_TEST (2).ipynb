# %% [markdown]
# # Welcome to Jupyter!

# %%
# !pip install auto-sklearn
import autosklearn
import matplotlib.pyplot as plt
# example of auto-sklearn for a classification dataset
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from autosklearn.classification import AutoSklearnClassifier
from sklearn.metrics import roc_curve, auc
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
# define dataset
X, y = make_classification(n_samples=100, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# define search
model = AutoSklearnClassifier(time_left_for_this_task=2*60, per_run_time_limit=30, n_jobs=8)
# perform the search
model.fit(X_train, y_train)
# summarize
print(model.sprint_statistics())
# evaluate best model
y_hat = model.predict(X_test)
acc = accuracy_score(y_test, y_hat)
print("Accuracy: %.3f" % acc)

# Compute ROC curve and ROC area for each class



# plot no skill roc curve
plt.plot([0, 1], [0, 1], linestyle='--', label='No Skill')
# calculate roc curve for model
fpr, tpr, _ = roc_curve(y_test, y_hat)
# plot model roc curve
plt.plot(fpr, tpr, marker='.', label='AutoSklearnClassifier')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()
no_skill = len(y_test[y_test==1]) / len(y_test)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# calculate model precision-recall curve
precision, recall, _ = precision_recall_curve(y_test, y_hat)
# plot the model precision-recall curve
plt.plot(recall, precision, marker='.', label='AutoSklearnClassifier')
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
# show the legend
plt.legend()
# show the plot
plt.show()
# Out:
# Requirement already satisfied: auto-sklearn in /srv/conda/envs/notebook/lib/python3.6/site-packages (0.12.7)
# Requirement already satisfied: dask in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (2021.3.0)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (5.4.1)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (0.24.2)
# Requirement already satisfied: pandas>=1.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (1.1.5)
# Requirement already satisfied: scipy<1.7,>=0.14.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (1.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (1.19.5)
# Requirement already satisfied: distributed>=2.2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (2021.3.0)
# Requirement already satisfied: smac<0.14,>=0.13.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (0.13.1)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.14 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (0.4.19)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (0.8.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (58.0.4)
# Requirement already satisfied: liac-arff in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (2.5.0)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (1.1.0)
# Requirement already satisfied: pynisher>=0.6.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from auto-sklearn) (0.6.4)
# Requirement already satisfied: pyparsing in /srv/conda/envs/notebook/lib/python3.6/site-packages (from ConfigSpace<0.5,>=0.4.14->auto-sklearn) (2.4.7)
# Requirement already satisfied: cython in /srv/conda/envs/notebook/lib/python3.6/site-packages (from ConfigSpace<0.5,>=0.4.14->auto-sklearn) (0.29.24)
# Requirement already satisfied: cloudpickle>=1.5.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (2.0.0)
# Requirement already satisfied: tornado>=5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (6.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (1.0.2)
# Requirement already satisfied: click>=6.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (8.0.3)
# Requirement already satisfied: zict>=0.1.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (2.0.0)
# Requirement already satisfied: contextvars in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (2.4)
# Requirement already satisfied: toolz>=0.8.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (0.11.1)
# Requirement already satisfied: psutil>=5.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from distributed>=2.2.0->auto-sklearn) (5.8.0)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from click>=6.6->distributed>=2.2.0->auto-sklearn) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas>=1.0->auto-sklearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->auto-sklearn) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from scikit-learn<0.25.0,>=0.24.0->auto-sklearn) (3.0.0)
# Requirement already satisfied: lazy-import in /srv/conda/envs/notebook/lib/python3.6/site-packages (from smac<0.14,>=0.13.1->auto-sklearn) (0.2.2)
# Requirement already satisfied: heapdict in /srv/conda/envs/notebook/lib/python3.6/site-packages (from zict>=0.1.3->distributed>=2.2.0->auto-sklearn) (1.0.1)
# Requirement already satisfied: immutables>=0.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from contextvars->distributed>=2.2.0->auto-sklearn) (0.16)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from immutables>=0.9->contextvars->distributed>=2.2.0->auto-sklearn) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-metadata->click>=6.6->distributed>=2.2.0->auto-sklearn) (3.6.0)
# auto-sklearn results:
#   Dataset name: 41d4b630-3b0f-11ec-818c-86f0b62b6432
#   Metric: accuracy
#   Best validation score: 0.956522
#   Number of target algorithm runs: 23
#   Number of successful target algorithm runs: 11
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 12
#   Number of target algorithms that exceeded the memory limit: 0
#
# Accuracy: 0.970

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.
